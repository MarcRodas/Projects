# %% [markdown]
# Install keras

# %%
# !pip3 install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (2.12.0)

# %% [markdown]
# Download data and uncompress

# %%
# !wget https://www.dropbox.com/s/zcwlujrtz3izcw8/gender.tgz
# !tar xvzf gender.tgz
# Out:
# --2023-04-15 09:35:42--  https://www.dropbox.com/s/zcwlujrtz3izcw8/gender.tgz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/zcwlujrtz3izcw8/gender.tgz [following]
# --2023-04-15 09:35:42--  https://www.dropbox.com/s/raw/zcwlujrtz3izcw8/gender.tgz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com/cd/0/inline/B6MAYtmsDnDvG4on1Z1ccv9BpTXo_ycXK0jmGv4wncO6_booyNeHhMG0ZOdTkTKtb-3ve5s1rkddzr6yLAiIpGtPx5v2Vk2_5vKf7_CiLyvfHs0ydaZsMxzwGJaj-Su60TkyYI8w58F2xY4s7Jz5KR-ya268GYF4d2ZwXulWkZ9Q4Q/file# [following]
# --2023-04-15 09:35:43--  https://uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com/cd/0/inline/B6MAYtmsDnDvG4on1Z1ccv9BpTXo_ycXK0jmGv4wncO6_booyNeHhMG0ZOdTkTKtb-3ve5s1rkddzr6yLAiIpGtPx5v2Vk2_5vKf7_CiLyvfHs0ydaZsMxzwGJaj-Su60TkyYI8w58F2xY4s7Jz5KR-ya268GYF4d2ZwXulWkZ9Q4Q/file
# Resolving uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com (uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com (uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/B6PPQwXhP8_E7-SJeLI5trajYvI7A-0kTBYXQBc8iWgkZdGbllmipBy5UkVHZdpAKyRi8mbIznK9GTmb0p1v2oH_BKNxPEGRgXoyL-3C4yZ0R3o5roarPSJ67uJjJobTgYPbYIVTk5zUCazB1HrCQCLc4N6Dozxx98Y4ebtqU1wjLtFlEvDjh7iT445cVLbovUJ7ceqKbAPEHi0ePGd4Aaj6ruWoSf27MeqUxLUH9pNt94UAFRbgIPnO-hfItu1ENNvOjGWWnMwATL3NaXMpB7P7n6SFxgjeJp5fWZywKzK3wjA_aJh78LjnfzXViYXOQCyvQUDul367Mc05INFCYu-BUMiQW3JHerEZIyNzcxJb__zfy7Hk_YbTQYaj4OIQ5zlaJQpfhXSr-waNJomRW_S_Qz2MO-_bQl8wP6TAsgoatg/file [following]
# --2023-04-15 09:35:43--  https://uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com/cd/0/inline2/B6PPQwXhP8_E7-SJeLI5trajYvI7A-0kTBYXQBc8iWgkZdGbllmipBy5UkVHZdpAKyRi8mbIznK9GTmb0p1v2oH_BKNxPEGRgXoyL-3C4yZ0R3o5roarPSJ67uJjJobTgYPbYIVTk5zUCazB1HrCQCLc4N6Dozxx98Y4ebtqU1wjLtFlEvDjh7iT445cVLbovUJ7ceqKbAPEHi0ePGd4Aaj6ruWoSf27MeqUxLUH9pNt94UAFRbgIPnO-hfItu1ENNvOjGWWnMwATL3NaXMpB7P7n6SFxgjeJp5fWZywKzK3wjA_aJh78LjnfzXViYXOQCyvQUDul367Mc05INFCYu-BUMiQW3JHerEZIyNzcxJb__zfy7Hk_YbTQYaj4OIQ5zlaJQpfhXSr-waNJomRW_S_Qz2MO-_bQl8wP6TAsgoatg/file
# Reusing existing connection to uc399f3fa121c61db85a6d1181c6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 348494455 (332M) [application/x-gtar]
# Saving to: ‘gender.tgz’
#
# gender.tgz          100%[===================>] 332.35M  17.7MB/s    in 16s
#
# 2023-04-15 09:36:00 (20.3 MB/s) - ‘gender.tgz’ saved [348494455/348494455]
#
# ./._x_test.npy
# x_test.npy
# ./._x_train.npy
# x_train.npy
# ./._y_test.npy
# y_test.npy
# ./._y_train.npy
# y_train.npy

# %% [markdown]
# Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization as BN
from keras.layers import GaussianNoise as GN
from keras.optimizers import SGD

from keras.callbacks import LearningRateScheduler as LRS
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler as LRS
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# Load and prepare data

# %%
# Load 
x_train = np.load('x_train.npy')
x_test = np.load('x_test.npy')

y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')

# Stats
print(x_train.shape)
print(y_train.shape)
print(sum(y_train == 1))
print(sum(y_train == 0))
print("{:.4f}".format(sum(y_train == 1)/y_train.shape[0]))
print(x_test.shape)
print(y_test.shape)
print(sum(y_test == 1))
print(sum(y_test == 0))
print("{:.4f}".format(sum(y_test == 1)/y_test.shape[0]))


## View some images
plt.imshow(x_train[0,:,:,: ] )
plt.show()


## Transforms
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = y_train.astype('float32')
y_test = y_test.astype('float32')


x_train /= 255
x_test /= 255

print(x_train.shape)
print(x_test.shape)


num_classes = 2

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# (10585, 100, 100, 3)
# (10585,)
# 2381
# 8204
# 0.2249
# (2648, 100, 100, 3)
# (2648,)
# 596
# 2052
# 0.2251
# (10585, 100, 100, 3)
# (2648, 100, 100, 3)

# %% [markdown]
# Create model, data augmentation etc...

# %%
## DEFINE A DATA AUGMENTATION GENERATOR

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range = 0.2)

# %%
batch_size = 64
epochs = 100

# %%
## DEF A BLOCK CONV + BN + GN + MAXPOOL
def CBGN(model,filters,ishape=0):
  if (ishape!=0):
    model.add(Conv2D(filters, (3, 3), padding='same',
                 input_shape=ishape))
  else:
    model.add(Conv2D(filters, (3, 3), padding='same'))
  
  model.add(BN())
  model.add(GN(0.1))
  model.add(Activation('relu'))
  model.add(Conv2D(filters, (3, 3), padding='same'))
  model.add(BN())
  model.add(GN(0.2))
  model.add(Activation('relu'))
  model.add(Conv2D(filters, (3, 3), padding='same'))
  model.add(BN())
  model.add(GN(0.3))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  
  return model

# %%
## DEF NN TOPOLOGY  
model = Sequential()

model=CBGN(model,32,x_train.shape[1:])

model=CBGN(model,64)
model.add(Dropout(0.1))

model=CBGN(model,128)
model.add(Dropout(0.2))

model=CBGN(model,256)
model.add(Dropout(0.3))

model=CBGN(model,512)
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))

model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  batch_normalization (BatchN  (None, 100, 100, 32)     128
#  ormalization)
#
#  gaussian_noise (GaussianNoi  (None, 100, 100, 32)     0
#  se)
#
#  activation (Activation)     (None, 100, 100, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 100, 100, 32)     128
#  hNormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 100, 100, 32)     0
#  oise)
#
#  activation_1 (Activation)   (None, 100, 100, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 100, 100, 32)      9248
#
#  batch_normalization_2 (Batc  (None, 100, 100, 32)     128
#  hNormalization)
#
#  gaussian_noise_2 (GaussianN  (None, 100, 100, 32)     0
#  oise)
#
#  activation_2 (Activation)   (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 50, 50, 64)       256
#  hNormalization)
#
#  gaussian_noise_3 (GaussianN  (None, 50, 50, 64)       0
#  oise)
#
#  activation_3 (Activation)   (None, 50, 50, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 64)        36928
#
#  batch_normalization_4 (Batc  (None, 50, 50, 64)       256
#  hNormalization)
#
#  gaussian_noise_4 (GaussianN  (None, 50, 50, 64)       0
#  oise)
#
#  activation_4 (Activation)   (None, 50, 50, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 50, 50, 64)       256
#  hNormalization)
#
#  gaussian_noise_5 (GaussianN  (None, 50, 50, 64)       0
#  oise)
#
#  activation_5 (Activation)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 25, 25, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  gaussian_noise_6 (GaussianN  (None, 25, 25, 128)      0
#  oise)
#
#  activation_6 (Activation)   (None, 25, 25, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 25, 25, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  gaussian_noise_7 (GaussianN  (None, 25, 25, 128)      0
#  oise)
#
#  activation_7 (Activation)   (None, 25, 25, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 25, 25, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  gaussian_noise_8 (GaussianN  (None, 25, 25, 128)      0
#  oise)
#
#  activation_8 (Activation)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_9 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  gaussian_noise_9 (GaussianN  (None, 12, 12, 256)      0
#  oise)
#
#  activation_9 (Activation)   (None, 12, 12, 256)       0
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_10 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  gaussian_noise_10 (Gaussian  (None, 12, 12, 256)      0
#  Noise)
#
#  activation_10 (Activation)  (None, 12, 12, 256)       0
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_11 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  gaussian_noise_11 (Gaussian  (None, 12, 12, 256)      0
#  Noise)
#
#  activation_11 (Activation)  (None, 12, 12, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 512)         1180160
#
#  batch_normalization_12 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  gaussian_noise_12 (Gaussian  (None, 6, 6, 512)        0
#  Noise)
#
#  activation_12 (Activation)  (None, 6, 6, 512)         0
#
#  conv2d_13 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_13 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  gaussian_noise_13 (Gaussian  (None, 6, 6, 512)        0
#  Noise)
#
#  activation_13 (Activation)  (None, 6, 6, 512)         0
#
#  conv2d_14 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_14 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  gaussian_noise_14 (Gaussian  (None, 6, 6, 512)        0
#  Noise)
#
#  activation_14 (Activation)  (None, 6, 6, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1024)              4719616
#
#  activation_15 (Activation)  (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 12,589,442
# Trainable params: 12,583,490
# Non-trainable params: 5,952
# _________________________________________________________________

# %%
# Early Stopping
es = EarlyStopping(
    monitor='val_loss',
    patience=100,
    verbose=1,
    mode=min
)
#Checkpoint
mc = ModelCheckpoint(
    'best_m.h5',
    monitor='val_accuracy',
    mode='max',
    verbose=1,
    save_best_only=True
)
# Out:
# WARNING:tensorflow:EarlyStopping mode <built-in function min> is unknown, fallback to auto mode.

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(patience = 15)

# %%
def plot_evolution(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
## TRAINING with DA
history=model.fit(datagen.flow(x_train, y_train,batch_size=batch_size),
                            steps_per_epoch=len(x_train) / batch_size, 
                            epochs=epochs,
                            validation_data=(x_test, y_test),
                            callbacks=[es,mc, reduce_lr],
                            verbose=2)
plot_evolution(history)
# Out:
# Epoch 1/100
#
# Epoch 1: val_accuracy improved from -inf to 0.77492, saving model to best_m.h5
# 165/165 - 74s - loss: 1.1483 - accuracy: 0.7505 - val_loss: 0.5957 - val_accuracy: 0.7749 - lr: 0.0010 - 74s/epoch - 448ms/step
# Epoch 2/100
#
# Epoch 2: val_accuracy did not improve from 0.77492
# 165/165 - 42s - loss: 0.5618 - accuracy: 0.7700 - val_loss: 0.5810 - val_accuracy: 0.7749 - lr: 0.0010 - 42s/epoch - 253ms/step
# Epoch 3/100
#
# Epoch 3: val_accuracy did not improve from 0.77492
# 165/165 - 42s - loss: 0.5455 - accuracy: 0.7721 - val_loss: 0.5949 - val_accuracy: 0.7749 - lr: 0.0010 - 42s/epoch - 254ms/step
# Epoch 4/100
#
# Epoch 4: val_accuracy did not improve from 0.77492
# 165/165 - 43s - loss: 0.5206 - accuracy: 0.7766 - val_loss: 0.5506 - val_accuracy: 0.7749 - lr: 0.0010 - 43s/epoch - 259ms/step
# Epoch 5/100
#
# Epoch 5: val_accuracy improved from 0.77492 to 0.79192, saving model to best_m.h5
# 165/165 - 42s - loss: 0.4904 - accuracy: 0.7865 - val_loss: 0.4980 - val_accuracy: 0.7919 - lr: 0.0010 - 42s/epoch - 257ms/step
# Epoch 6/100
#
# Epoch 6: val_accuracy did not improve from 0.79192
# 165/165 - 42s - loss: 0.4649 - accuracy: 0.7977 - val_loss: 0.7460 - val_accuracy: 0.5083 - lr: 0.0010 - 42s/epoch - 254ms/step
# Epoch 7/100
#
# Epoch 7: val_accuracy improved from 0.79192 to 0.79494, saving model to best_m.h5
# 165/165 - 42s - loss: 0.4228 - accuracy: 0.8173 - val_loss: 0.4524 - val_accuracy: 0.7949 - lr: 0.0010 - 42s/epoch - 254ms/step
# Epoch 8/100
#
# Epoch 8: val_accuracy improved from 0.79494 to 0.85196, saving model to best_m.h5
# 165/165 - 42s - loss: 0.3690 - accuracy: 0.8387 - val_loss: 0.3545 - val_accuracy: 0.8520 - lr: 0.0010 - 42s/epoch - 251ms/step
# Epoch 9/100
#
# Epoch 9: val_accuracy improved from 0.85196 to 0.90257, saving model to best_m.h5
# 165/165 - 42s - loss: 0.2869 - accuracy: 0.8832 - val_loss: 0.2293 - val_accuracy: 0.9026 - lr: 0.0010 - 42s/epoch - 255ms/step
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.90257
# 165/165 - 42s - loss: 0.2295 - accuracy: 0.9085 - val_loss: 0.3074 - val_accuracy: 0.8935 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 11/100
#
# Epoch 11: val_accuracy improved from 0.90257 to 0.92069, saving model to best_m.h5
# 165/165 - 41s - loss: 0.2012 - accuracy: 0.9236 - val_loss: 0.1985 - val_accuracy: 0.9207 - lr: 0.0010 - 41s/epoch - 250ms/step
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.92069
# 165/165 - 42s - loss: 0.1773 - accuracy: 0.9310 - val_loss: 0.3096 - val_accuracy: 0.9060 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 13/100
#
# Epoch 13: val_accuracy improved from 0.92069 to 0.95317, saving model to best_m.h5
# 165/165 - 43s - loss: 0.1680 - accuracy: 0.9348 - val_loss: 0.1373 - val_accuracy: 0.9532 - lr: 0.0010 - 43s/epoch - 258ms/step
# Epoch 14/100
#
# Epoch 14: val_accuracy did not improve from 0.95317
# 165/165 - 41s - loss: 0.1567 - accuracy: 0.9399 - val_loss: 0.2466 - val_accuracy: 0.9052 - lr: 0.0010 - 41s/epoch - 246ms/step
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.95317
# 165/165 - 42s - loss: 0.1452 - accuracy: 0.9448 - val_loss: 0.3660 - val_accuracy: 0.8327 - lr: 0.0010 - 42s/epoch - 254ms/step
# Epoch 16/100
#
# Epoch 16: val_accuracy improved from 0.95317 to 0.95506, saving model to best_m.h5
# 165/165 - 41s - loss: 0.1336 - accuracy: 0.9491 - val_loss: 0.1345 - val_accuracy: 0.9551 - lr: 0.0010 - 41s/epoch - 248ms/step
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.95506
# 165/165 - 40s - loss: 0.1328 - accuracy: 0.9483 - val_loss: 0.2367 - val_accuracy: 0.9048 - lr: 0.0010 - 40s/epoch - 245ms/step
# Epoch 18/100
#
# Epoch 18: val_accuracy did not improve from 0.95506
# 165/165 - 42s - loss: 0.1272 - accuracy: 0.9521 - val_loss: 0.2040 - val_accuracy: 0.9388 - lr: 0.0010 - 42s/epoch - 255ms/step
# Epoch 19/100
#
# Epoch 19: val_accuracy improved from 0.95506 to 0.96752, saving model to best_m.h5
# 165/165 - 41s - loss: 0.1196 - accuracy: 0.9564 - val_loss: 0.0828 - val_accuracy: 0.9675 - lr: 0.0010 - 41s/epoch - 249ms/step
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.96752
# 165/165 - 42s - loss: 0.1127 - accuracy: 0.9585 - val_loss: 0.1023 - val_accuracy: 0.9622 - lr: 0.0010 - 42s/epoch - 256ms/step
# Epoch 21/100
#
# Epoch 21: val_accuracy did not improve from 0.96752
# 165/165 - 41s - loss: 0.1039 - accuracy: 0.9621 - val_loss: 0.1012 - val_accuracy: 0.9596 - lr: 0.0010 - 41s/epoch - 246ms/step
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.96752
# 165/165 - 42s - loss: 0.1027 - accuracy: 0.9634 - val_loss: 0.1037 - val_accuracy: 0.9637 - lr: 0.0010 - 42s/epoch - 256ms/step
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.96752
# 165/165 - 42s - loss: 0.1080 - accuracy: 0.9598 - val_loss: 0.1139 - val_accuracy: 0.9573 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 24/100
#
# Epoch 24: val_accuracy improved from 0.96752 to 0.97508, saving model to best_m.h5
# 165/165 - 43s - loss: 0.0992 - accuracy: 0.9619 - val_loss: 0.0788 - val_accuracy: 0.9751 - lr: 0.0010 - 43s/epoch - 258ms/step
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.97508
# 165/165 - 43s - loss: 0.0977 - accuracy: 0.9642 - val_loss: 0.0907 - val_accuracy: 0.9709 - lr: 0.0010 - 43s/epoch - 257ms/step
# Epoch 26/100
#
# Epoch 26: val_accuracy did not improve from 0.97508
# 165/165 - 42s - loss: 0.0894 - accuracy: 0.9683 - val_loss: 0.1522 - val_accuracy: 0.9479 - lr: 0.0010 - 42s/epoch - 256ms/step
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.97508
# 165/165 - 41s - loss: 0.0819 - accuracy: 0.9700 - val_loss: 0.1187 - val_accuracy: 0.9592 - lr: 0.0010 - 41s/epoch - 246ms/step
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.97508
# 165/165 - 41s - loss: 0.0833 - accuracy: 0.9692 - val_loss: 0.2798 - val_accuracy: 0.8795 - lr: 0.0010 - 41s/epoch - 251ms/step
# Epoch 29/100
#
# Epoch 29: val_accuracy did not improve from 0.97508
# 165/165 - 41s - loss: 0.0807 - accuracy: 0.9704 - val_loss: 0.4787 - val_accuracy: 0.8150 - lr: 0.0010 - 41s/epoch - 245ms/step
# Epoch 30/100
#
# Epoch 30: val_accuracy improved from 0.97508 to 0.97659, saving model to best_m.h5
# 165/165 - 43s - loss: 0.0785 - accuracy: 0.9678 - val_loss: 0.0666 - val_accuracy: 0.9766 - lr: 0.0010 - 43s/epoch - 262ms/step
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.97659
# 165/165 - 41s - loss: 0.0798 - accuracy: 0.9710 - val_loss: 0.1826 - val_accuracy: 0.9211 - lr: 0.0010 - 41s/epoch - 250ms/step
# Epoch 32/100
#
# Epoch 32: val_accuracy did not improve from 0.97659
# 165/165 - 41s - loss: 0.0750 - accuracy: 0.9735 - val_loss: 0.1492 - val_accuracy: 0.9456 - lr: 0.0010 - 41s/epoch - 247ms/step
# Epoch 33/100
#
# Epoch 33: val_accuracy improved from 0.97659 to 0.97772, saving model to best_m.h5
# 165/165 - 42s - loss: 0.0695 - accuracy: 0.9739 - val_loss: 0.0615 - val_accuracy: 0.9777 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 34/100
#
# Epoch 34: val_accuracy improved from 0.97772 to 0.98036, saving model to best_m.h5
# 165/165 - 41s - loss: 0.0683 - accuracy: 0.9751 - val_loss: 0.0676 - val_accuracy: 0.9804 - lr: 0.0010 - 41s/epoch - 251ms/step
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.98036
# 165/165 - 40s - loss: 0.0642 - accuracy: 0.9766 - val_loss: 0.0882 - val_accuracy: 0.9705 - lr: 0.0010 - 40s/epoch - 243ms/step
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.98036
# 165/165 - 42s - loss: 0.0682 - accuracy: 0.9739 - val_loss: 0.0635 - val_accuracy: 0.9747 - lr: 0.0010 - 42s/epoch - 253ms/step
# Epoch 37/100
#
# Epoch 37: val_accuracy did not improve from 0.98036
# 165/165 - 40s - loss: 0.0614 - accuracy: 0.9774 - val_loss: 0.0992 - val_accuracy: 0.9690 - lr: 0.0010 - 40s/epoch - 243ms/step
# Epoch 38/100
#
# Epoch 38: val_accuracy did not improve from 0.98036
# 165/165 - 41s - loss: 0.0651 - accuracy: 0.9756 - val_loss: 0.0646 - val_accuracy: 0.9792 - lr: 0.0010 - 41s/epoch - 249ms/step
# Epoch 39/100
#
# Epoch 39: val_accuracy improved from 0.98036 to 0.98074, saving model to best_m.h5
# 165/165 - 42s - loss: 0.0592 - accuracy: 0.9780 - val_loss: 0.0535 - val_accuracy: 0.9807 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.98074
# 165/165 - 42s - loss: 0.0578 - accuracy: 0.9797 - val_loss: 0.0762 - val_accuracy: 0.9773 - lr: 0.0010 - 42s/epoch - 251ms/step
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.98074
# 165/165 - 42s - loss: 0.0571 - accuracy: 0.9777 - val_loss: 0.0941 - val_accuracy: 0.9717 - lr: 0.0010 - 42s/epoch - 256ms/step
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.98074
# 165/165 - 41s - loss: 0.0560 - accuracy: 0.9795 - val_loss: 0.0618 - val_accuracy: 0.9766 - lr: 0.0010 - 41s/epoch - 250ms/step
# Epoch 43/100
#
# Epoch 43: val_accuracy improved from 0.98074 to 0.98489, saving model to best_m.h5
# 165/165 - 41s - loss: 0.0550 - accuracy: 0.9795 - val_loss: 0.0517 - val_accuracy: 0.9849 - lr: 0.0010 - 41s/epoch - 251ms/step
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0548 - accuracy: 0.9789 - val_loss: 0.0531 - val_accuracy: 0.9789 - lr: 0.0010 - 41s/epoch - 247ms/step
# Epoch 45/100
#
# Epoch 45: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0529 - accuracy: 0.9806 - val_loss: 0.0513 - val_accuracy: 0.9841 - lr: 0.0010 - 41s/epoch - 248ms/step
# Epoch 46/100
#
# Epoch 46: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0557 - accuracy: 0.9807 - val_loss: 0.0832 - val_accuracy: 0.9645 - lr: 0.0010 - 41s/epoch - 249ms/step
# Epoch 47/100
#
# Epoch 47: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0499 - accuracy: 0.9829 - val_loss: 0.1125 - val_accuracy: 0.9566 - lr: 0.0010 - 41s/epoch - 250ms/step
# Epoch 48/100
#
# Epoch 48: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0488 - accuracy: 0.9832 - val_loss: 0.0641 - val_accuracy: 0.9796 - lr: 0.0010 - 41s/epoch - 249ms/step
# Epoch 49/100
#
# Epoch 49: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0460 - accuracy: 0.9825 - val_loss: 0.0690 - val_accuracy: 0.9758 - lr: 0.0010 - 42s/epoch - 253ms/step
# Epoch 50/100
#
# Epoch 50: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0515 - accuracy: 0.9806 - val_loss: 0.0591 - val_accuracy: 0.9789 - lr: 0.0010 - 42s/epoch - 253ms/step
# Epoch 51/100
#
# Epoch 51: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0520 - accuracy: 0.9814 - val_loss: 0.0730 - val_accuracy: 0.9739 - lr: 0.0010 - 41s/epoch - 248ms/step
# Epoch 52/100
#
# Epoch 52: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0494 - accuracy: 0.9838 - val_loss: 0.0693 - val_accuracy: 0.9815 - lr: 0.0010 - 42s/epoch - 251ms/step
# Epoch 53/100
#
# Epoch 53: val_accuracy did not improve from 0.98489
# 165/165 - 40s - loss: 0.0473 - accuracy: 0.9830 - val_loss: 0.0553 - val_accuracy: 0.9811 - lr: 0.0010 - 40s/epoch - 243ms/step
# Epoch 54/100
#
# Epoch 54: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0415 - accuracy: 0.9841 - val_loss: 0.0723 - val_accuracy: 0.9819 - lr: 0.0010 - 42s/epoch - 252ms/step
# Epoch 55/100
#
# Epoch 55: val_accuracy did not improve from 0.98489
# 165/165 - 40s - loss: 0.0434 - accuracy: 0.9831 - val_loss: 0.0665 - val_accuracy: 0.9777 - lr: 0.0010 - 40s/epoch - 243ms/step
# Epoch 56/100
#
# Epoch 56: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0457 - accuracy: 0.9834 - val_loss: 0.1487 - val_accuracy: 0.9494 - lr: 0.0010 - 41s/epoch - 249ms/step
# Epoch 57/100
#
# Epoch 57: val_accuracy did not improve from 0.98489
# 165/165 - 41s - loss: 0.0427 - accuracy: 0.9853 - val_loss: 0.0787 - val_accuracy: 0.9773 - lr: 0.0010 - 41s/epoch - 248ms/step
# Epoch 58/100
#
# Epoch 58: val_accuracy did not improve from 0.98489
# 165/165 - 40s - loss: 0.0400 - accuracy: 0.9842 - val_loss: 0.0799 - val_accuracy: 0.9694 - lr: 0.0010 - 40s/epoch - 243ms/step
# Epoch 59/100
#
# Epoch 59: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0385 - accuracy: 0.9864 - val_loss: 0.0686 - val_accuracy: 0.9781 - lr: 0.0010 - 42s/epoch - 254ms/step
# Epoch 60/100
#
# Epoch 60: val_accuracy did not improve from 0.98489
# 165/165 - 42s - loss: 0.0428 - accuracy: 0.9840 - val_loss: 0.0578 - val_accuracy: 0.9804 - lr: 0.0010 - 42s/epoch - 253ms/step
# Epoch 61/100
#
# Epoch 61: val_accuracy improved from 0.98489 to 0.98754, saving model to best_m.h5
# 165/165 - 43s - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.0451 - val_accuracy: 0.9875 - lr: 1.0000e-04 - 43s/epoch - 259ms/step
# Epoch 62/100
#
# Epoch 62: val_accuracy did not improve from 0.98754
# 165/165 - 41s - loss: 0.0229 - accuracy: 0.9907 - val_loss: 0.0497 - val_accuracy: 0.9864 - lr: 1.0000e-04 - 41s/epoch - 249ms/step
# Epoch 63/100
#
# Epoch 63: val_accuracy improved from 0.98754 to 0.98867, saving model to best_m.h5
# 165/165 - 42s - loss: 0.0204 - accuracy: 0.9922 - val_loss: 0.0453 - val_accuracy: 0.9887 - lr: 1.0000e-04 - 42s/epoch - 253ms/step
# Epoch 64/100
#
# Epoch 64: val_accuracy did not improve from 0.98867
# 165/165 - 41s - loss: 0.0179 - accuracy: 0.9928 - val_loss: 0.0544 - val_accuracy: 0.9879 - lr: 1.0000e-04 - 41s/epoch - 250ms/step
# Epoch 65/100
#
# Epoch 65: val_accuracy did not improve from 0.98867
# 165/165 - 41s - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.0543 - val_accuracy: 0.9875 - lr: 1.0000e-04 - 41s/epoch - 250ms/step
# Epoch 66/100
#
# Epoch 66: val_accuracy did not improve from 0.98867
# 165/165 - 42s - loss: 0.0163 - accuracy: 0.9939 - val_loss: 0.0603 - val_accuracy: 0.9887 - lr: 1.0000e-04 - 42s/epoch - 256ms/step
# Epoch 67/100
#
# Epoch 67: val_accuracy did not improve from 0.98867
# 165/165 - 42s - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.0583 - val_accuracy: 0.9856 - lr: 1.0000e-04 - 42s/epoch - 254ms/step
# Epoch 68/100
#
# Epoch 68: val_accuracy improved from 0.98867 to 0.98905, saving model to best_m.h5
# 165/165 - 43s - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.0524 - val_accuracy: 0.9890 - lr: 1.0000e-04 - 43s/epoch - 259ms/step
# Epoch 69/100
#
# Epoch 69: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0605 - val_accuracy: 0.9868 - lr: 1.0000e-04 - 40s/epoch - 244ms/step
# Epoch 70/100
#
# Epoch 70: val_accuracy did not improve from 0.98905
# 165/165 - 42s - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.0594 - val_accuracy: 0.9887 - lr: 1.0000e-04 - 42s/epoch - 255ms/step
# Epoch 71/100
#
# Epoch 71: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0570 - val_accuracy: 0.9868 - lr: 1.0000e-04 - 41s/epoch - 246ms/step
# Epoch 72/100
#
# Epoch 72: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.0561 - val_accuracy: 0.9887 - lr: 1.0000e-04 - 41s/epoch - 245ms/step
# Epoch 73/100
#
# Epoch 73: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0119 - accuracy: 0.9951 - val_loss: 0.0620 - val_accuracy: 0.9879 - lr: 1.0000e-04 - 41s/epoch - 250ms/step
# Epoch 74/100
#
# Epoch 74: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0133 - accuracy: 0.9948 - val_loss: 0.0603 - val_accuracy: 0.9879 - lr: 1.0000e-04 - 40s/epoch - 242ms/step
# Epoch 75/100
#
# Epoch 75: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.0600 - val_accuracy: 0.9883 - lr: 1.0000e-04 - 40s/epoch - 242ms/step
# Epoch 76/100
#
# Epoch 76: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.0593 - val_accuracy: 0.9864 - lr: 1.0000e-04 - 40s/epoch - 243ms/step
# Epoch 77/100
#
# Epoch 77: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.0614 - val_accuracy: 0.9887 - lr: 1.0000e-05 - 41s/epoch - 246ms/step
# Epoch 78/100
#
# Epoch 78: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0619 - val_accuracy: 0.9890 - lr: 1.0000e-05 - 40s/epoch - 241ms/step
# Epoch 79/100
#
# Epoch 79: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0630 - val_accuracy: 0.9883 - lr: 1.0000e-05 - 40s/epoch - 241ms/step
# Epoch 80/100
#
# Epoch 80: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.0637 - val_accuracy: 0.9883 - lr: 1.0000e-05 - 41s/epoch - 245ms/step
# Epoch 81/100
#
# Epoch 81: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0640 - val_accuracy: 0.9875 - lr: 1.0000e-05 - 41s/epoch - 246ms/step
# Epoch 82/100
#
# Epoch 82: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0099 - accuracy: 0.9961 - val_loss: 0.0634 - val_accuracy: 0.9875 - lr: 1.0000e-05 - 41s/epoch - 247ms/step
# Epoch 83/100
#
# Epoch 83: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0638 - val_accuracy: 0.9875 - lr: 1.0000e-05 - 40s/epoch - 245ms/step
# Epoch 84/100
#
# Epoch 84: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0099 - accuracy: 0.9958 - val_loss: 0.0650 - val_accuracy: 0.9879 - lr: 1.0000e-05 - 40s/epoch - 242ms/step
# Epoch 85/100
#
# Epoch 85: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.0652 - val_accuracy: 0.9879 - lr: 1.0000e-05 - 40s/epoch - 243ms/step
# Epoch 86/100
#
# Epoch 86: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0653 - val_accuracy: 0.9879 - lr: 1.0000e-05 - 40s/epoch - 244ms/step
# Epoch 87/100
#
# Epoch 87: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0650 - val_accuracy: 0.9879 - lr: 1.0000e-05 - 41s/epoch - 248ms/step
# Epoch 88/100
#
# Epoch 88: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0654 - val_accuracy: 0.9879 - lr: 1.0000e-05 - 40s/epoch - 243ms/step
# Epoch 89/100
#
# Epoch 89: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0655 - val_accuracy: 0.9883 - lr: 1.0000e-05 - 41s/epoch - 245ms/step
# Epoch 90/100
#
# Epoch 90: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0675 - val_accuracy: 0.9883 - lr: 1.0000e-05 - 41s/epoch - 245ms/step
# Epoch 91/100
#
# Epoch 91: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.0679 - val_accuracy: 0.9872 - lr: 1.0000e-05 - 41s/epoch - 249ms/step
# Epoch 92/100
#
# Epoch 92: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0675 - val_accuracy: 0.9872 - lr: 1.0000e-06 - 40s/epoch - 244ms/step
# Epoch 93/100
#
# Epoch 93: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0670 - val_accuracy: 0.9875 - lr: 1.0000e-06 - 41s/epoch - 248ms/step
# Epoch 94/100
#
# Epoch 94: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0669 - val_accuracy: 0.9879 - lr: 1.0000e-06 - 41s/epoch - 247ms/step
# Epoch 95/100
#
# Epoch 95: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0671 - val_accuracy: 0.9872 - lr: 1.0000e-06 - 41s/epoch - 250ms/step
# Epoch 96/100
#
# Epoch 96: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0672 - val_accuracy: 0.9872 - lr: 1.0000e-06 - 41s/epoch - 249ms/step
# Epoch 97/100
#
# Epoch 97: val_accuracy did not improve from 0.98905
# 165/165 - 41s - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0674 - val_accuracy: 0.9875 - lr: 1.0000e-06 - 41s/epoch - 248ms/step
# Epoch 98/100
#
# Epoch 98: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0675 - val_accuracy: 0.9875 - lr: 1.0000e-06 - 40s/epoch - 244ms/step
# Epoch 99/100
#
# Epoch 99: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0672 - val_accuracy: 0.9879 - lr: 1.0000e-06 - 40s/epoch - 244ms/step
# Epoch 100/100
#
# Epoch 100: val_accuracy did not improve from 0.98905
# 165/165 - 40s - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0672 - val_accuracy: 0.9879 - lr: 1.0000e-06 - 40s/epoch - 242ms/step

# %%
## TEST
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 83/83 [==============================] - 2s 24ms/step - loss: 0.0672 - accuracy: 0.9879
# Test loss: 0.06722521781921387
# Test accuracy: 0.9879153966903687

# %%
from tensorflow.keras.models import load_model

# %%
# load the saved model
saved_model = load_model('best_m.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(x_train, y_train, verbose=0)
_, test_acc = saved_model.evaluate(x_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.999, Test: 0.989
